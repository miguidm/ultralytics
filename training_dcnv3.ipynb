# %%
import os

os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

import torch

from ultralytics import YOLO

# Check GPU availability
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"✅ Using GPU: {torch.cuda.get_device_name(0)}")
else: 
    device = torch.device("cpu")
    print("⚠️ GPU not available, using CPU instead.")
# Out:
# /home/migui/miniconda3/envs/dcn/lib/python3.10/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# ✅ Using GPU: NVIDIA GeForce RTX 3060

# %%
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# 2.1.0+cu121
# 12.1
# True

# %%
import os

# Force all caches to user's home directory
cache_base = os.path.expanduser("~/.cache")
os.environ["TORCH_HOME"] = f"{cache_base}/torch"
os.environ["HF_HOME"] = f"{cache_base}/huggingface"
os.environ["PIP_CACHE_DIR"] = f"{cache_base}/pip"

# Make sure folders exist
for path in [os.environ["TORCH_HOME"], os.environ["HF_HOME"], os.environ["PIP_CACHE_DIR"]]:
    os.makedirs(path, exist_ok=True)

print("✅ Using custom cache directories:")
print("TORCH_HOME:", os.environ["TORCH_HOME"])
print("HF_HOME:", os.environ["HF_HOME"])
print("PIP_CACHE_DIR:", os.environ["PIP_CACHE_DIR"])
# Out:
# ✅ Using custom cache directories:
# TORCH_HOME: /home/migui/.cache/torch
# HF_HOME: /home/migui/.cache/huggingface
# PIP_CACHE_DIR: /home/migui/.cache/pip

# %%
import os

print(os.path.exists("100data.yaml"))
# Out:
# True

# %%
from ultralytics import YOLO

# Resume from last checkpoint
model = YOLO('/home/migui/YOLO_outputs/100_dcnv3_yolov8m_neck_pan/weights/last.pt')   
results = model.train(resume=True)
# Out:
# New https://pypi.org/project/ultralytics/8.3.234 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.223 🚀 Python-3.10.19 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 11901MiB)
# ...

# %%
import os
import sys
import torch
from ultralytics import YOLO

# Add ultralytics root to Python path for DCNv3 imports
ultralytics_root = "/media/mydrive/GitHub/ultralytics"
if ultralytics_root not in sys.path:
    sys.path.insert(0, ultralytics_root)

# Pick up environment variable or default to user's home directory  
project_dir = os.getenv("YOLO_OUTPUT", os.path.expanduser("~/YOLO_outputs"))

print("Loading DCNv3-YOLOv8 model...")
model = YOLO("/media/mydrive/GitHub/ultralytics/ultralytics/cfg/models/v8/dcnv3-yolov8-liu.yaml")

print("Starting training...")
results = model.train(
    data="100data.yaml",
    project=project_dir,
    name="100_dcnv3_yolov8m_liu_second",
    epochs=300,
    patience=50,
    imgsz=640,
    batch=16,
    workers=0,  # Single-threaded data loading (slower but more stable)
    device=0,   # Use GPU 0
)

print(f"✅ Training completed. Check {project_dir}/100_dcnv3_yolov8m_fpn for results.")
# Out:
# Loading DCNv3-YOLOv8 model...
# /media/mydrive/GitHub/ultralytics/ops_dcnv3/modules/dcnv3.py:257: UserWarning: You'd better set channels in DCNv3 to make the dimension of each attention head a power of 2 which is more efficient in our CUDA implementation.
#   warnings.warn(
# Starting training...
# New https://pypi.org/project/ultralytics/8.4.0 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.223 🚀 Python-3.10.19 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 11901MiB)
# ...

# %%
from ultralytics import YOLO

# Resume from last checkpoint
model = YOLO('/home/migui/YOLO_outputs/100_dcnv3_yolov8m_liu_second/weights/last.pt')   
results = model.train(resume=True)
# Out:
# /media/mydrive/GitHub/ultralytics/ops_dcnv3/functions/dcnv3_func.py:23: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(
# /media/mydrive/GitHub/ultralytics/ops_dcnv3/functions/dcnv3_func.py:59: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# New https://pypi.org/project/ultralytics/8.4.4 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.223 🚀 Python-3.10.19 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 11901MiB)
# ...

# %%
from ultralytics import YOLO

# Resume from last checkpoint
model = YOLO('/home/migui/YOLO_outputs/100_dcnv3_yolov8m_full_second/weights/last.pt')   
results = model.train(resume=True)
# Out:
# /home/migui/miniconda3/envs/dcn/lib/python3.10/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /media/mydrive/GitHub/ultralytics/ops_dcnv3/functions/dcnv3_func.py:23: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(
# /media/mydrive/GitHub/ultralytics/ops_dcnv3/functions/dcnv3_func.py:59: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# ...

# %%
import os
import sys
import torch
from ultralytics import YOLO

# Add ultralytics root to Python path for DCNv3 imports
ultralytics_root = "/media/mydrive/GitHub/ultralytics"
if ultralytics_root not in sys.path:
    sys.path.insert(0, ultralytics_root)

# Pick up environment variable or default to user's home directory  
project_dir = os.getenv("YOLO_OUTPUT", os.path.expanduser("~/YOLO_outputs"))

print("Loading DCNv3-YOLOv8 model...")
model = YOLO("/media/mydrive/GitHub/ultralytics/ultralytics/cfg/models/v8/dcnv3-yolov8-neck-fpn.yaml")

print("Starting training...")
results = model.train(
    data="100data.yaml",
    project=project_dir,
    name="100_dcnv3_yolov8m_fpn_second",
    epochs=300,
    patience=50,
    imgsz=640,
    batch=16,
    workers=0,  # Single-threaded data loading (slower but more stable)
    device=0,   # Use GPU 0
)

print(f"✅ Training completed. Check {project_dir}/100_dcnv3_yolov8m_fpn for results.")
# Out:
# Loading DCNv3-YOLOv8 model...
# /media/mydrive/GitHub/ultralytics/ops_dcnv3/modules/dcnv3.py:257: UserWarning: You'd better set channels in DCNv3 to make the dimension of each attention head a power of 2 which is more efficient in our CUDA implementation.
#   warnings.warn(
# Starting training...
# New https://pypi.org/project/ultralytics/8.4.7 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.223 🚀 Python-3.10.19 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 11901MiB)
# ...

# %%
from ultralytics import YOLO

# Resume from last checkpoint
model = YOLO('/home/migui/YOLO_outputs/100_dcnv3_yolov8m_fpn_second/weights/last.pt')   
results = model.train(resume=True)
# Out:
# /home/migui/miniconda3/envs/dcn/lib/python3.10/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# New https://pypi.org/project/ultralytics/8.4.7 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.223 🚀 Python-3.10.19 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 11901MiB)
# ...

# %%
import os
import sys
import torch
from ultralytics import YOLO

# Add ultralytics root to Python path for DCNv3 imports
ultralytics_root = "/media/mydrive/GitHub/ultralytics"
if ultralytics_root not in sys.path:
    sys.path.insert(0, ultralytics_root)

# Pick up environment variable or default to user's home directory  
project_dir = os.getenv("YOLO_OUTPUT", os.path.expanduser("~/YOLO_outputs"))

print("Loading DCNv3-YOLOv8 model...")
model = YOLO("/media/mydrive/GitHub/ultralytics/ultralytics/cfg/models/v8/dcnv3-yolov8-neck-pan.yaml")

print("Starting training...")
results = model.train(
    data="100data.yaml",
    project=project_dir,
    name="100_dcnv3_yolov8m_pan_second",
    epochs=300,
    patience=50,
    imgsz=640,
    batch=16,
    workers=0,  # Single-threaded data loading (slower but more stable)
    device=0,   # Use GPU 0
)

print(f"✅ Training completed. Check {project_dir}/100_dcnv3_yolov8m_fpn for results.")
